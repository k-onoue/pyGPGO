# %%
from dataclasses import dataclass, field
from typing import Optional, Dict, Union, Literal

import torch
from gpytorch.constraints import Interval, GreaterThan, Positive
from gpytorch.kernels import RBFKernel, MaternKernel, ScaleKernel
from gpytorch.priors import GammaPrior, Prior
from torch.nn.functional import softplus


@dataclass
class Priors:
    lengthscale_prior: Prior = field(default_factory=lambda: GammaPrior(3.0, 0.5))
    outputscale_prior: Prior = field(default_factory=lambda: GammaPrior(3.0, 0.5))
    noise_prior: Prior = field(default_factory=lambda: GammaPrior(1.1, 0.05))
    df_prior: Prior = field(default_factory=lambda: GammaPrior(2.0, 0.15))

@dataclass
class Constraints:
    lengthscale_constraint: Interval = field(default_factory=Positive)
    outputscale_constraint: Interval = field(default_factory=Positive)
    noise_constraint: Interval = field(default_factory=Positive)
    df_constraint: Interval = field(default_factory=lambda: GreaterThan(2 + 1e-4))

@dataclass
class Device:
    device: torch.device = torch.device("cpu")
    dtype: torch.dtype = torch.float


@dataclass
class ModelConfig:
    ard_num_dims: Optional[int]  # Changed to Optional[int]
    kernel_type: Literal["rbf", "matern32", "matern52"] = "rbf"
    priors: Priors = field(default_factory=Priors)
    constraints: Constraints = field(default_factory=Constraints)
    device: Device = field(default_factory=Device)
    trained_params: Optional[Dict[str, Union[float, torch.Tensor]]] = None


def kronDelta(X, Xstar):
    return (X.unsqueeze(1) == Xstar.unsqueeze(0)).all(dim=2).float()


# ======================
# Kernel Creation Function
# ======================

def create_kernel(config: ModelConfig):
    """
    Creates the kernel for the GP or TP model based on the specified kernel type.
    """
    # Select base kernel based on kernel_type
    if config.kernel_type == "rbf":
        base_kernel = RBFKernel(
            ard_num_dims=config.ard_num_dims,
            lengthscale_prior=config.priors.lengthscale_prior
            if not (config.trained_params and "lengthscale" in config.trained_params)
            else None,
            lengthscale_constraint=config.constraints.lengthscale_constraint,
        )
    elif config.kernel_type == "matern32":
        base_kernel = MaternKernel(
            nu=1.5,
            ard_num_dims=config.ard_num_dims,
            lengthscale_prior=config.priors.lengthscale_prior
            if not (config.trained_params and "lengthscale" in config.trained_params)
            else None,
            lengthscale_constraint=config.constraints.lengthscale_constraint,
        )
    elif config.kernel_type == "matern52":
        base_kernel = MaternKernel(
            nu=2.5,
            ard_num_dims=config.ard_num_dims,
            lengthscale_prior=config.priors.lengthscale_prior
            if not (config.trained_params and "lengthscale" in config.trained_params)
            else None,
            lengthscale_constraint=config.constraints.lengthscale_constraint,
        )
    else:
        raise ValueError("Invalid kernel type specified. Choose from 'rbf', 'matern32', or 'matern52'.")

    # Set trained lengthscale if available
    if config.trained_params and "lengthscale" in config.trained_params:
        lengthscale_value = torch.tensor(config.trained_params["lengthscale"]).to(
            device=config.device.device, dtype=config.device.dtype
        )
        # Adjust shape based on ard_num_dims
        if config.ard_num_dims is not None:
            # ARD case: lengthscale is of shape (1, ard_num_dims, 1)
            lengthscale_value = lengthscale_value.view(1, config.ard_num_dims, 1)
        else:
            # Non-ARD case: lengthscale is scalar
            lengthscale_value = lengthscale_value
        base_kernel.initialize(lengthscale=lengthscale_value)

    # Wrap the base kernel with ScaleKernel
    kernel = ScaleKernel(
        base_kernel=base_kernel,
        outputscale_prior=config.priors.outputscale_prior
        if not (config.trained_params and "outputscale" in config.trained_params)
        else None,
        outputscale_constraint=config.constraints.outputscale_constraint,
    )

    # Set trained outputscale if available
    if config.trained_params and "outputscale" in config.trained_params:
        outputscale_value = torch.tensor(config.trained_params["outputscale"]).to(
            device=config.device.device, dtype=config.device.dtype
        )
        kernel.initialize(outputscale=outputscale_value)

    return kernel


# ======================
# CovFunc Class with Noise Handling using kronDelta
# ======================

class CovFunc:
    def __init__(self, config: ModelConfig):
        """
        Covariance function wrapper with noise handling for Gaussian Process kernels.
        
        Parameters
        ----------
        config : ModelConfig
            Configuration object that includes kernel type, priors, constraints, and noise settings.
        """
        self.config = config
        self.kernel = create_kernel(config)
        
        # Set noise level as a trainable parameter
        if config.trained_params and "noise" in config.trained_params:
            self.raw_noise = torch.nn.Parameter(
                torch.tensor(config.trained_params["noise"], device=config.device.device, dtype=config.device.dtype)
            )
        else:
            # Initialize with the mean of the noise prior if not specified in trained_params
            self.raw_noise = torch.nn.Parameter(
                torch.tensor(config.priors.noise_prior.mean, device=config.device.device, dtype=config.device.dtype)
            )

    @property
    def noise(self):
        """Apply softplus to ensure noise is positive."""
        return softplus(self.raw_noise)
    
    def get_params(self) -> Dict[str, torch.Tensor]:
        """
        Returns a dictionary of trainable parameters for optimization.

        Returns
        -------
        list
            List of trainable parameters (raw lengthscale, outputscale, noise).
        """
        return {
            "lengthscale": self.kernel.base_kernel.raw_lengthscale,
            "outputscale": self.kernel.raw_outputscale,
            "noise": self.raw_noise
        }

    def K(self, X, Xstar):
        """
        Computes the covariance matrix including noise using kronDelta.

        Parameters
        ----------
        X : torch.Tensor, shape=(n_samples, n_features)
            Input data.
        Xstar : torch.Tensor, shape=(m_samples, n_features)
            Input data for prediction.

        Returns
        -------
        torch.Tensor
            Covariance matrix with noise component.
        """

        # Kernel matrix computation
        K = self.kernel(X, Xstar).evaluate()
        
        # Add observation noise
        K += self.noise * kronDelta(X, Xstar)
        
        return K

# ======================
# Sample Usage
# ======================

# Config with Specific Kernel Type and Initial Values for Lengthscale, Outputscale, and Noise
config = ModelConfig(
    ard_num_dims=None,  # Set to None for non-ARD (scalar lengthscale)
    kernel_type="matern32",  # "rbf", "matern32", or "matern52"
    trained_params={"lengthscale": 1.0, "outputscale": 1.0, "noise": 0.1}
)

cov_func = CovFunc(config)

# Example data
X = torch.tensor([[1.0], [2.0], [3.0]])
K = cov_func.K(X, X)  # X and Xstar are the same, so noise is added

# ======================
# Print Results
# ======================

print("Covariance matrix with noise:\n", K)
print(f"kernel: \n{cov_func.kernel}\n")
print(f"lengthscale: {cov_func.kernel.base_kernel.lengthscale.item()}")
print(f"outputscale: {cov_func.kernel.outputscale.item()}")
# Out:
# Covariance matrix with noise:
#  tensor([[1.7444, 0.4834, 0.1397],
#         [0.4834, 1.7444, 0.4834],
#         [0.1397, 0.4834, 1.7444]], grad_fn=<AddBackward0>)
# kernel:
# ScaleKernel(
#   (base_kernel): MaternKernel(
#     (raw_lengthscale_constraint): Positive()
#   )
#   (raw_outputscale_constraint): Positive()
# )
#
# lengthscale: 1.0
# outputscale: 1.0

# %%
import torch
import torch.optim as optim

class GaussianProcess:
    def __init__(self, covfunc, optimize=False, mprior=0.0):
        """
        Gaussian Process regressor class using PyTorch.

        Parameters
        ----------
        covfunc : instance of CovFunc
            Covariance function implementing K(X, Xstar).
        optimize : bool
            Whether to perform hyperparameter optimization.
        mprior : float
            Prior mean of the Gaussian Process.
        """
        self.covfunc = covfunc
        self.optimize = optimize
        self.mprior = mprior

    def get_params(self) -> Dict[str, float]:
        """
        Returns the covariance function hyperparameters.

        Returns
        -------
        dict
            Dictionary of hyperparameters.
        """
        params = self.covfunc.get_params()
        params = params.values()
        # params = {k: v.item() for k, v in params.items()}
        return params

    def fit(self, X, y):
        """
        Fits the Gaussian Process model to the data.
        """
        # self.X = torch.tensor(X, dtype=torch.float32)
        # self.y = torch.tensor(y, dtype=torch.float32)
        self.X = X.to(self.covfunc.config.device.device, self.covfunc.config.device.dtype)
        self.y = y.to(self.covfunc.config.device.device, self.covfunc.config.device.dtype)
        self.n_samples = X.shape[0]
        if self.optimize:
            self._optimize_hyperparameters()

        # Compute posterior parameters
        self._compute_posterior()

    def _compute_posterior(self):
        """
        Computes the posterior distribution of the Gaussian Process.
        """
        K = self.covfunc.K(self.X, self.X)
        self.L = torch.linalg.cholesky(K)
        self.alpha = torch.cholesky_solve((self.y - self.mprior).unsqueeze(1), self.L)
        self.alpha = self.alpha.squeeze()

        # Compute log marginal likelihood
        y_centered = self.y - self.mprior
        self.logp = -0.5 * torch.dot(y_centered, self.alpha)
        self.logp -= torch.sum(torch.log(torch.diag(self.L)))
        self.logp -= self.n_samples / 2 * torch.log(torch.tensor(2 * torch.pi))

    def _optimize_hyperparameters(self, n_steps=1000, lr=0.01):
        """
        Optimizes the hyperparameters of the covariance function.

        Parameters
        ----------
        n_steps : int
            Number of optimization steps.
        lr : float
            Learning rate for the optimizer.
        """
        params = self.get_params()

        optimizer = optim.Adam(params, lr=lr)

        # Optimization loop
        for _ in range(n_steps):
            optimizer.zero_grad()
            self._compute_posterior()
            loss = - self.logp
            loss.backward()
            optimizer.step()
            
            print(f"Iter: {_}, Log Marginal Likelihood: {self.logp.item()}")

    def predict(self, Xstar, return_std=False):
        """
        Makes predictions using the Gaussian Process model.

        Parameters
        ----------
        Xstar : torch.Tensor, shape=(n_test_samples, n_features)
            Test inputs.
        return_std : bool
            If True, returns the standard deviation of the predictions.

        Returns
        -------
        fmean : torch.Tensor, shape=(n_test_samples,)
            Predictive mean at test inputs.
        fcov : torch.Tensor or None
            Predictive covariance matrix or standard deviations.
        """
        k_star = self.covfunc.K(self.X, Xstar)
        fmean = self.mprior + torch.matmul(k_star.t(), self.alpha)

        v = torch.cholesky_solve(k_star, self.L)
        K_star = self.covfunc.K(Xstar, Xstar)
        fcov = K_star - torch.matmul(k_star.t(), v)

        if return_std:
            fcov = torch.sqrt(torch.diag(fcov))

        return fmean, fcov

    def update(self, x_new, y_new):
        """
        Updates the model with new observations.

        Parameters
        ----------
        x_new : torch.Tensor, shape=(n_new_samples, n_features)
            New training inputs.
        y_new : torch.Tensor, shape=(n_new_samples,)
            New training targets.
        """
        self.X = torch.cat((self.X, x_new), dim=0)
        self.y = torch.cat((self.y, y_new), dim=0)
        self.n_samples = self.X.shape[0]
        if self.optimize:
            self._optimize_hyperparameters()
        else:
            self._compute_posterior()

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# Generate synthetic data
torch.manual_seed(42)
X_train = torch.linspace(0, 10, 20).unsqueeze(1)  # Shape (20, 1)
y_train = torch.sin(X_train).squeeze() + 0.2 * torch.randn(X_train.size(0))  # Shape (20,)

# Define ModelConfig with initial parameters
config = ModelConfig(
    ard_num_dims=1,          # 1D input, no ARD
    kernel_type="matern32",   # Using Matern 3/2 kernel
    trained_params={"lengthscale": 1.0, "outputscale": 1.0, "noise": 0.1}
)

# Initialize CovFunc with config
cov_func = CovFunc(config)

# Initialize GaussianProcess with cov_func and enable hyperparameter optimization
gp = GaussianProcess(cov_func, optimize=True, mprior=0.0)

# Fit the model to training data
gp.fit(X_train, y_train)

# Generate test data for prediction
X_test = torch.linspace(0, 10, 100).unsqueeze(1)

# Make predictions with the trained GP model
fmean, fcov = gp.predict(X_test, return_std=True)

# Plot the results
fmean = fmean.detach().numpy()
std_dev = fcov.detach().numpy() if isinstance(fcov, torch.Tensor) else np.sqrt(np.diag(fcov))

# Plot training data, predictive mean, and confidence intervals
plt.figure(figsize=(10, 6))
plt.plot(X_train.numpy(), y_train.numpy(), 'o', label='Training Data')
plt.plot(X_test.numpy(), fmean, 'r', label='Predictive Mean')
plt.fill_between(X_test.numpy().flatten(),
                 fmean - 1.96 * std_dev,
                 fmean + 1.96 * std_dev,
                 color='pink', alpha=0.5, label='95% Confidence Interval')
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.title("Gaussian Process Regression with Optimized Hyperparameters")
plt.show()

# Print optimized parameters
print("Optimized lengthscale:", gp.covfunc.kernel.base_kernel.lengthscale.item())
print("Optimized outputscale:", gp.covfunc.kernel.outputscale.item())
print("Optimized noise:", gp.covfunc.noise.item())
# Out:
# Iter: 0, Log Marginal Likelihood: -23.52143096923828
# Iter: 1, Log Marginal Likelihood: -23.450693130493164
# Iter: 2, Log Marginal Likelihood: -23.379980087280273
# Iter: 3, Log Marginal Likelihood: -23.30929183959961
# Iter: 4, Log Marginal Likelihood: -23.238636016845703
# Iter: 5, Log Marginal Likelihood: -23.168010711669922
# Iter: 6, Log Marginal Likelihood: -23.097421646118164
# Iter: 7, Log Marginal Likelihood: -23.02687644958496
# Iter: 8, Log Marginal Likelihood: -22.956371307373047
# Iter: 9, Log Marginal Likelihood: -22.885913848876953
# Iter: 10, Log Marginal Likelihood: -22.815507888793945
# Iter: 11, Log Marginal Likelihood: -22.745155334472656
# Iter: 12, Log Marginal Likelihood: -22.674863815307617
# Iter: 13, Log Marginal Likelihood: -22.60462760925293
# Iter: 14, Log Marginal Likelihood: -22.534460067749023
# Iter: 15, Log Marginal Likelihood: -22.46435546875
# Iter: 16, Log Marginal Likelihood: -22.39432716369629
# Iter: 17, Log Marginal Likelihood: -22.32437515258789
# Iter: 18, Log Marginal Likelihood: -22.254499435424805
# Iter: 19, Log Marginal Likelihood: -22.184703826904297
# Iter: 20, Log Marginal Likelihood: -22.11499786376953
# Iter: 21, Log Marginal Likelihood: -22.045377731323242
# Iter: 22, Log Marginal Likelihood: -21.975852966308594
# Iter: 23, Log Marginal Likelihood: -21.906423568725586
# Iter: 24, Log Marginal Likelihood: -21.837095260620117
# Iter: 25, Log Marginal Likelihood: -21.767868041992188
# Iter: 26, Log Marginal Likelihood: -21.698749542236328
# Iter: 27, Log Marginal Likelihood: -21.629743576049805
# Iter: 28, Log Marginal Likelihood: -21.560848236083984
# Iter: 29, Log Marginal Likelihood: -21.49207305908203
# Iter: 30, Log Marginal Likelihood: -21.423416137695312
# Iter: 31, Log Marginal Likelihood: -21.354883193969727
# Iter: 32, Log Marginal Likelihood: -21.286479949951172
# Iter: 33, Log Marginal Likelihood: -21.21820831298828
# Iter: 34, Log Marginal Likelihood: -21.150070190429688
# Iter: 35, Log Marginal Likelihood: -21.082069396972656
# Iter: 36, Log Marginal Likelihood: -21.014211654663086
# Iter: 37, Log Marginal Likelihood: -20.946495056152344
# Iter: 38, Log Marginal Likelihood: -20.878929138183594
# Iter: 39, Log Marginal Likelihood: -20.811511993408203
# Iter: 40, Log Marginal Likelihood: -20.744251251220703
# Iter: 41, Log Marginal Likelihood: -20.677148818969727
# Iter: 42, Log Marginal Likelihood: -20.610206604003906
# Iter: 43, Log Marginal Likelihood: -20.543426513671875
# Iter: 44, Log Marginal Likelihood: -20.47681427001953
# Iter: 45, Log Marginal Likelihood: -20.410369873046875
# Iter: 46, Log Marginal Likelihood: -20.344100952148438
# Iter: 47, Log Marginal Likelihood: -20.27800750732422
# Iter: 48, Log Marginal Likelihood: -20.212093353271484
# Iter: 49, Log Marginal Likelihood: -20.1463623046875
# Iter: 50, Log Marginal Likelihood: -20.080814361572266
# Iter: 51, Log Marginal Likelihood: -20.015453338623047
# Iter: 52, Log Marginal Likelihood: -19.95028305053711
# Iter: 53, Log Marginal Likelihood: -19.88530921936035
# Iter: 54, Log Marginal Likelihood: -19.82052993774414
# Iter: 55, Log Marginal Likelihood: -19.75594711303711
# Iter: 56, Log Marginal Likelihood: -19.69156837463379
# Iter: 57, Log Marginal Likelihood: -19.627391815185547
# Iter: 58, Log Marginal Likelihood: -19.563425064086914
# Iter: 59, Log Marginal Likelihood: -19.499664306640625
# Iter: 60, Log Marginal Likelihood: -19.436115264892578
# Iter: 61, Log Marginal Likelihood: -19.372777938842773
# Iter: 62, Log Marginal Likelihood: -19.309659957885742
# Iter: 63, Log Marginal Likelihood: -19.246761322021484
# Iter: 64, Log Marginal Likelihood: -19.184078216552734
# Iter: 65, Log Marginal Likelihood: -19.12162208557129
# Iter: 66, Log Marginal Likelihood: -19.059389114379883
# Iter: 67, Log Marginal Likelihood: -18.99738121032715
# Iter: 68, Log Marginal Likelihood: -18.935604095458984
# Iter: 69, Log Marginal Likelihood: -18.874055862426758
# Iter: 70, Log Marginal Likelihood: -18.812740325927734
# Iter: 71, Log Marginal Likelihood: -18.751659393310547
# Iter: 72, Log Marginal Likelihood: -18.69080924987793
# Iter: 73, Log Marginal Likelihood: -18.63020133972168
# Iter: 74, Log Marginal Likelihood: -18.569828033447266
# Iter: 75, Log Marginal Likelihood: -18.509695053100586
# Iter: 76, Log Marginal Likelihood: -18.44980239868164
# Iter: 77, Log Marginal Likelihood: -18.39015769958496
# Iter: 78, Log Marginal Likelihood: -18.330751419067383
# Iter: 79, Log Marginal Likelihood: -18.271587371826172
# Iter: 80, Log Marginal Likelihood: -18.212671279907227
# Iter: 81, Log Marginal Likelihood: -18.15399932861328
# Iter: 82, Log Marginal Likelihood: -18.09557342529297
# Iter: 83, Log Marginal Likelihood: -18.037399291992188
# Iter: 84, Log Marginal Likelihood: -17.979469299316406
# Iter: 85, Log Marginal Likelihood: -17.92178726196289
# Iter: 86, Log Marginal Likelihood: -17.86435317993164
# Iter: 87, Log Marginal Likelihood: -17.80716896057129
# Iter: 88, Log Marginal Likelihood: -17.750232696533203
# Iter: 89, Log Marginal Likelihood: -17.693546295166016
# Iter: 90, Log Marginal Likelihood: -17.637107849121094
# Iter: 91, Log Marginal Likelihood: -17.580915451049805
# Iter: 92, Log Marginal Likelihood: -17.524972915649414
# Iter: 93, Log Marginal Likelihood: -17.46927833557129
# Iter: 94, Log Marginal Likelihood: -17.413829803466797
# Iter: 95, Log Marginal Likelihood: -17.358631134033203
# Iter: 96, Log Marginal Likelihood: -17.30367660522461
# Iter: 97, Log Marginal Likelihood: -17.248966217041016
# Iter: 98, Log Marginal Likelihood: -17.19449806213379
# Iter: 99, Log Marginal Likelihood: -17.140277862548828
# Iter: 100, Log Marginal Likelihood: -17.08629608154297
# Iter: 101, Log Marginal Likelihood: -17.03255844116211
# Iter: 102, Log Marginal Likelihood: -16.97905921936035
# Iter: 103, Log Marginal Likelihood: -16.925796508789062
# Iter: 104, Log Marginal Likelihood: -16.872772216796875
# Iter: 105, Log Marginal Likelihood: -16.819982528686523
# Iter: 106, Log Marginal Likelihood: -16.767425537109375
# Iter: 107, Log Marginal Likelihood: -16.715103149414062
# Iter: 108, Log Marginal Likelihood: -16.663007736206055
# Iter: 109, Log Marginal Likelihood: -16.611141204833984
# Iter: 110, Log Marginal Likelihood: -16.55950164794922
# Iter: 111, Log Marginal Likelihood: -16.508089065551758
# Iter: 112, Log Marginal Likelihood: -16.456897735595703
# Iter: 113, Log Marginal Likelihood: -16.405921936035156
# Iter: 114, Log Marginal Likelihood: -16.355167388916016
# Iter: 115, Log Marginal Likelihood: -16.30462646484375
# Iter: 116, Log Marginal Likelihood: -16.254302978515625
# Iter: 117, Log Marginal Likelihood: -16.20418930053711
# Iter: 118, Log Marginal Likelihood: -16.154281616210938
# Iter: 119, Log Marginal Likelihood: -16.104581832885742
# Iter: 120, Log Marginal Likelihood: -16.055084228515625
# Iter: 121, Log Marginal Likelihood: -16.00579261779785
# Iter: 122, Log Marginal Likelihood: -15.95669937133789
# Iter: 123, Log Marginal Likelihood: -15.907800674438477
# Iter: 124, Log Marginal Likelihood: -15.859095573425293
# Iter: 125, Log Marginal Likelihood: -15.81058120727539
# Iter: 126, Log Marginal Likelihood: -15.762258529663086
# Iter: 127, Log Marginal Likelihood: -15.714122772216797
# Iter: 128, Log Marginal Likelihood: -15.666169166564941
# Iter: 129, Log Marginal Likelihood: -15.618398666381836
# Iter: 130, Log Marginal Likelihood: -15.57080364227295
# Iter: 131, Log Marginal Likelihood: -15.523387908935547
# Iter: 132, Log Marginal Likelihood: -15.476146697998047
# Iter: 133, Log Marginal Likelihood: -15.429079055786133
# Iter: 134, Log Marginal Likelihood: -15.382179260253906
# Iter: 135, Log Marginal Likelihood: -15.335448265075684
# Iter: 136, Log Marginal Likelihood: -15.288881301879883
# Iter: 137, Log Marginal Likelihood: -15.242477416992188
# Iter: 138, Log Marginal Likelihood: -15.196233749389648
# Iter: 139, Log Marginal Likelihood: -15.150151252746582
# Iter: 140, Log Marginal Likelihood: -15.104225158691406
# Iter: 141, Log Marginal Likelihood: -15.058451652526855
# Iter: 142, Log Marginal Likelihood: -15.012834548950195
# Iter: 143, Log Marginal Likelihood: -14.967368125915527
# Iter: 144, Log Marginal Likelihood: -14.922049522399902
# Iter: 145, Log Marginal Likelihood: -14.876880645751953
# Iter: 146, Log Marginal Likelihood: -14.831855773925781
# Iter: 147, Log Marginal Likelihood: -14.786980628967285
# Iter: 148, Log Marginal Likelihood: -14.742244720458984
# Iter: 149, Log Marginal Likelihood: -14.697653770446777
# Iter: 150, Log Marginal Likelihood: -14.653200149536133
# Iter: 151, Log Marginal Likelihood: -14.60888957977295
# Iter: 152, Log Marginal Likelihood: -14.564715385437012
# Iter: 153, Log Marginal Likelihood: -14.520679473876953
# Iter: 154, Log Marginal Likelihood: -14.476781845092773
# Iter: 155, Log Marginal Likelihood: -14.433019638061523
# Iter: 156, Log Marginal Likelihood: -14.389392852783203
# Iter: 157, Log Marginal Likelihood: -14.34589958190918
# Iter: 158, Log Marginal Likelihood: -14.302539825439453
# Iter: 159, Log Marginal Likelihood: -14.25931167602539
# Iter: 160, Log Marginal Likelihood: -14.216215133666992
# Iter: 161, Log Marginal Likelihood: -14.173254013061523
# Iter: 162, Log Marginal Likelihood: -14.130424499511719
# Iter: 163, Log Marginal Likelihood: -14.087724685668945
# Iter: 164, Log Marginal Likelihood: -14.045157432556152
# Iter: 165, Log Marginal Likelihood: -14.00271987915039
# Iter: 166, Log Marginal Likelihood: -13.960411071777344
# Iter: 167, Log Marginal Likelihood: -13.918235778808594
# Iter: 168, Log Marginal Likelihood: -13.876195907592773
# Iter: 169, Log Marginal Likelihood: -13.834280967712402
# Iter: 170, Log Marginal Likelihood: -13.792497634887695
# Iter: 171, Log Marginal Likelihood: -13.750845909118652
# Iter: 172, Log Marginal Likelihood: -13.70932674407959
# Iter: 173, Log Marginal Likelihood: -13.667938232421875
# Iter: 174, Log Marginal Likelihood: -13.626678466796875
# Iter: 175, Log Marginal Likelihood: -13.585552215576172
# Iter: 176, Log Marginal Likelihood: -13.544554710388184
# Iter: 177, Log Marginal Likelihood: -13.503695487976074
# Iter: 178, Log Marginal Likelihood: -13.462965965270996
# Iter: 179, Log Marginal Likelihood: -13.422370910644531
# Iter: 180, Log Marginal Likelihood: -13.381904602050781
# Iter: 181, Log Marginal Likelihood: -13.34157657623291
# Iter: 182, Log Marginal Likelihood: -13.301379203796387
# Iter: 183, Log Marginal Likelihood: -13.261319160461426
# Iter: 184, Log Marginal Likelihood: -13.221391677856445
# Iter: 185, Log Marginal Likelihood: -13.181598663330078
# Iter: 186, Log Marginal Likelihood: -13.141944885253906
# Iter: 187, Log Marginal Likelihood: -13.102420806884766
# Iter: 188, Log Marginal Likelihood: -13.06303882598877
# Iter: 189, Log Marginal Likelihood: -13.02379035949707
# Iter: 190, Log Marginal Likelihood: -12.984676361083984
# Iter: 191, Log Marginal Likelihood: -12.945706367492676
# Iter: 192, Log Marginal Likelihood: -12.906871795654297
# Iter: 193, Log Marginal Likelihood: -12.868173599243164
# Iter: 194, Log Marginal Likelihood: -12.829614639282227
# Iter: 195, Log Marginal Likelihood: -12.791194915771484
# Iter: 196, Log Marginal Likelihood: -12.752915382385254
# Iter: 197, Log Marginal Likelihood: -12.71477222442627
# Iter: 198, Log Marginal Likelihood: -12.676774978637695
# Iter: 199, Log Marginal Likelihood: -12.638914108276367
# Iter: 200, Log Marginal Likelihood: -12.601194381713867
# Iter: 201, Log Marginal Likelihood: -12.563615798950195
# Iter: 202, Log Marginal Likelihood: -12.526183128356934
# Iter: 203, Log Marginal Likelihood: -12.488887786865234
# Iter: 204, Log Marginal Likelihood: -12.451737403869629
# Iter: 205, Log Marginal Likelihood: -12.414729118347168
# Iter: 206, Log Marginal Likelihood: -12.377861022949219
# Iter: 207, Log Marginal Likelihood: -12.341137886047363
# Iter: 208, Log Marginal Likelihood: -12.304559707641602
# Iter: 209, Log Marginal Likelihood: -12.268122673034668
# Iter: 210, Log Marginal Likelihood: -12.231834411621094
# Iter: 211, Log Marginal Likelihood: -12.195686340332031
# Iter: 212, Log Marginal Likelihood: -12.159685134887695
# Iter: 213, Log Marginal Likelihood: -12.123826026916504
# Iter: 214, Log Marginal Likelihood: -12.088111877441406
# Iter: 215, Log Marginal Likelihood: -12.05255126953125
# Iter: 216, Log Marginal Likelihood: -12.017129898071289
# Iter: 217, Log Marginal Likelihood: -11.981858253479004
# Iter: 218, Log Marginal Likelihood: -11.946730613708496
# Iter: 219, Log Marginal Likelihood: -11.911750793457031
# Iter: 220, Log Marginal Likelihood: -11.876914978027344
# Iter: 221, Log Marginal Likelihood: -11.842233657836914
# Iter: 222, Log Marginal Likelihood: -11.807697296142578
# Iter: 223, Log Marginal Likelihood: -11.773307800292969
# Iter: 224, Log Marginal Likelihood: -11.739065170288086
# Iter: 225, Log Marginal Likelihood: -11.704970359802246
# Iter: 226, Log Marginal Likelihood: -11.671024322509766
# Iter: 227, Log Marginal Likelihood: -11.637235641479492
# Iter: 228, Log Marginal Likelihood: -11.603588104248047
# Iter: 229, Log Marginal Likelihood: -11.570093154907227
# Iter: 230, Log Marginal Likelihood: -11.536746978759766
# Iter: 231, Log Marginal Likelihood: -11.503551483154297
# Iter: 232, Log Marginal Likelihood: -11.470504760742188
# Iter: 233, Log Marginal Likelihood: -11.43760871887207
# Iter: 234, Log Marginal Likelihood: -11.404861450195312
# Iter: 235, Log Marginal Likelihood: -11.372268676757812
# Iter: 236, Log Marginal Likelihood: -11.339829444885254
# Iter: 237, Log Marginal Likelihood: -11.307535171508789
# Iter: 238, Log Marginal Likelihood: -11.275400161743164
# Iter: 239, Log Marginal Likelihood: -11.243412017822266
# Iter: 240, Log Marginal Likelihood: -11.211575508117676
# Iter: 241, Log Marginal Likelihood: -11.179892539978027
# Iter: 242, Log Marginal Likelihood: -11.14836311340332
# Iter: 243, Log Marginal Likelihood: -11.116986274719238
# Iter: 244, Log Marginal Likelihood: -11.085758209228516
# Iter: 245, Log Marginal Likelihood: -11.05468463897705
# Iter: 246, Log Marginal Likelihood: -11.023763656616211
# Iter: 247, Log Marginal Likelihood: -10.992997169494629
# Iter: 248, Log Marginal Likelihood: -10.962385177612305
# Iter: 249, Log Marginal Likelihood: -10.931930541992188
# Iter: 250, Log Marginal Likelihood: -10.901622772216797
# Iter: 251, Log Marginal Likelihood: -10.87147045135498
# Iter: 252, Log Marginal Likelihood: -10.841470718383789
# Iter: 253, Log Marginal Likelihood: -10.811630249023438
# Iter: 254, Log Marginal Likelihood: -10.781942367553711
# Iter: 255, Log Marginal Likelihood: -10.752405166625977
# Iter: 256, Log Marginal Likelihood: -10.723027229309082
# Iter: 257, Log Marginal Likelihood: -10.693801879882812
# Iter: 258, Log Marginal Likelihood: -10.664734840393066
# Iter: 259, Log Marginal Likelihood: -10.635817527770996
# Iter: 260, Log Marginal Likelihood: -10.607050895690918
# Iter: 261, Log Marginal Likelihood: -10.578453063964844
# Iter: 262, Log Marginal Likelihood: -10.54999828338623
# Iter: 263, Log Marginal Likelihood: -10.521703720092773
# Iter: 264, Log Marginal Likelihood: -10.493559837341309
# Iter: 265, Log Marginal Likelihood: -10.46557331085205
# Iter: 266, Log Marginal Likelihood: -10.437742233276367
# Iter: 267, Log Marginal Likelihood: -10.410067558288574
# Iter: 268, Log Marginal Likelihood: -10.382542610168457
# Iter: 269, Log Marginal Likelihood: -10.355178833007812
# Iter: 270, Log Marginal Likelihood: -10.327966690063477
# Iter: 271, Log Marginal Likelihood: -10.300914764404297
# Iter: 272, Log Marginal Likelihood: -10.27401351928711
# Iter: 273, Log Marginal Likelihood: -10.24726390838623
# Iter: 274, Log Marginal Likelihood: -10.220674514770508
# Iter: 275, Log Marginal Likelihood: -10.194238662719727
# Iter: 276, Log Marginal Likelihood: -10.167959213256836
# Iter: 277, Log Marginal Likelihood: -10.141831398010254
# Iter: 278, Log Marginal Likelihood: -10.115860939025879
# Iter: 279, Log Marginal Likelihood: -10.090042114257812
# Iter: 280, Log Marginal Likelihood: -10.064384460449219
# Iter: 281, Log Marginal Likelihood: -10.038873672485352
# Iter: 282, Log Marginal Likelihood: -10.013525009155273
# Iter: 283, Log Marginal Likelihood: -9.988316535949707
# Iter: 284, Log Marginal Likelihood: -9.963274002075195
# Iter: 285, Log Marginal Likelihood: -9.938383102416992
# Iter: 286, Log Marginal Likelihood: -9.913647651672363
# Iter: 287, Log Marginal Likelihood: -9.88906192779541
# Iter: 288, Log Marginal Likelihood: -9.864633560180664
# Iter: 289, Log Marginal Likelihood: -9.840354919433594
# Iter: 290, Log Marginal Likelihood: -9.816229820251465
# Iter: 291, Log Marginal Likelihood: -9.792255401611328
# Iter: 292, Log Marginal Likelihood: -9.768434524536133
# Iter: 293, Log Marginal Likelihood: -9.744771957397461
# Iter: 294, Log Marginal Likelihood: -9.721257209777832
# Iter: 295, Log Marginal Likelihood: -9.697895050048828
# Iter: 296, Log Marginal Likelihood: -9.67467975616455
# Iter: 297, Log Marginal Likelihood: -9.651623725891113
# Iter: 298, Log Marginal Likelihood: -9.628713607788086
# Iter: 299, Log Marginal Likelihood: -9.60595703125
# Iter: 300, Log Marginal Likelihood: -9.583345413208008
# Iter: 301, Log Marginal Likelihood: -9.560891151428223
# Iter: 302, Log Marginal Likelihood: -9.538582801818848
# Iter: 303, Log Marginal Likelihood: -9.516429901123047
# Iter: 304, Log Marginal Likelihood: -9.494421005249023
# Iter: 305, Log Marginal Likelihood: -9.472559928894043
# Iter: 306, Log Marginal Likelihood: -9.450851440429688
# Iter: 307, Log Marginal Likelihood: -9.429293632507324
# Iter: 308, Log Marginal Likelihood: -9.407876968383789
# Iter: 309, Log Marginal Likelihood: -9.386608123779297
# Iter: 310, Log Marginal Likelihood: -9.365496635437012
# Iter: 311, Log Marginal Likelihood: -9.344518661499023
# Iter: 312, Log Marginal Likelihood: -9.323698997497559
# Iter: 313, Log Marginal Likelihood: -9.303020477294922
# Iter: 314, Log Marginal Likelihood: -9.282487869262695
# Iter: 315, Log Marginal Likelihood: -9.26209831237793
# Iter: 316, Log Marginal Likelihood: -9.241857528686523
# Iter: 317, Log Marginal Likelihood: -9.221763610839844
# Iter: 318, Log Marginal Likelihood: -9.201807975769043
# Iter: 319, Log Marginal Likelihood: -9.182004928588867
# Iter: 320, Log Marginal Likelihood: -9.162333488464355
# Iter: 321, Log Marginal Likelihood: -9.142815589904785
# Iter: 322, Log Marginal Likelihood: -9.123428344726562
# Iter: 323, Log Marginal Likelihood: -9.104186058044434
# Iter: 324, Log Marginal Likelihood: -9.085084915161133
# Iter: 325, Log Marginal Likelihood: -9.066128730773926
# Iter: 326, Log Marginal Likelihood: -9.047313690185547
# Iter: 327, Log Marginal Likelihood: -9.02863597869873
# Iter: 328, Log Marginal Likelihood: -9.010102272033691
# Iter: 329, Log Marginal Likelihood: -8.991703033447266
# Iter: 330, Log Marginal Likelihood: -8.973443984985352
# Iter: 331, Log Marginal Likelihood: -8.955318450927734
# Iter: 332, Log Marginal Likelihood: -8.937332153320312
# Iter: 333, Log Marginal Likelihood: -8.919486999511719
# Iter: 334, Log Marginal Likelihood: -8.90177059173584
# Iter: 335, Log Marginal Likelihood: -8.88420581817627
# Iter: 336, Log Marginal Likelihood: -8.866758346557617
# Iter: 337, Log Marginal Likelihood: -8.849451065063477
# Iter: 338, Log Marginal Likelihood: -8.832274436950684
# Iter: 339, Log Marginal Likelihood: -8.815242767333984
# Iter: 340, Log Marginal Likelihood: -8.798330307006836
# Iter: 341, Log Marginal Likelihood: -8.781556129455566
# Iter: 342, Log Marginal Likelihood: -8.764914512634277
# Iter: 343, Log Marginal Likelihood: -8.748408317565918
# Iter: 344, Log Marginal Likelihood: -8.73202133178711
# Iter: 345, Log Marginal Likelihood: -8.715781211853027
# Iter: 346, Log Marginal Likelihood: -8.699651718139648
# Iter: 347, Log Marginal Likelihood: -8.683652877807617
# Iter: 348, Log Marginal Likelihood: -8.66779899597168
# Iter: 349, Log Marginal Likelihood: -8.652058601379395
# Iter: 350, Log Marginal Likelihood: -8.636444091796875
# Iter: 351, Log Marginal Likelihood: -8.620965957641602
# Iter: 352, Log Marginal Likelihood: -8.60560417175293
# Iter: 353, Log Marginal Likelihood: -8.590378761291504
# Iter: 354, Log Marginal Likelihood: -8.57525634765625
# Iter: 355, Log Marginal Likelihood: -8.560279846191406
# Iter: 356, Log Marginal Likelihood: -8.545418739318848
# Iter: 357, Log Marginal Likelihood: -8.530679702758789
# Iter: 358, Log Marginal Likelihood: -8.516057014465332
# Iter: 359, Log Marginal Likelihood: -8.501559257507324
# Iter: 360, Log Marginal Likelihood: -8.487184524536133
# Iter: 361, Log Marginal Likelihood: -8.47292709350586
# Iter: 362, Log Marginal Likelihood: -8.458792686462402
# Iter: 363, Log Marginal Likelihood: -8.444767951965332
# Iter: 364, Log Marginal Likelihood: -8.430868148803711
# Iter: 365, Log Marginal Likelihood: -8.417083740234375
# Iter: 366, Log Marginal Likelihood: -8.403419494628906
# Iter: 367, Log Marginal Likelihood: -8.38985538482666
# Iter: 368, Log Marginal Likelihood: -8.376423835754395
# Iter: 369, Log Marginal Likelihood: -8.363088607788086
# Iter: 370, Log Marginal Likelihood: -8.349891662597656
# Iter: 371, Log Marginal Likelihood: -8.336787223815918
# Iter: 372, Log Marginal Likelihood: -8.323797225952148
# Iter: 373, Log Marginal Likelihood: -8.310933113098145
# Iter: 374, Log Marginal Likelihood: -8.298177719116211
# Iter: 375, Log Marginal Likelihood: -8.285501480102539
# Iter: 376, Log Marginal Likelihood: -8.272972106933594
# Iter: 377, Log Marginal Likelihood: -8.260540962219238
# Iter: 378, Log Marginal Likelihood: -8.248210906982422
# Iter: 379, Log Marginal Likelihood: -8.235991477966309
# Iter: 380, Log Marginal Likelihood: -8.223889350891113
# Iter: 381, Log Marginal Likelihood: -8.211874961853027
# Iter: 382, Log Marginal Likelihood: -8.199978828430176
# Iter: 383, Log Marginal Likelihood: -8.188176155090332
# Iter: 384, Log Marginal Likelihood: -8.176483154296875
# Iter: 385, Log Marginal Likelihood: -8.164899826049805
# Iter: 386, Log Marginal Likelihood: -8.153401374816895
# Iter: 387, Log Marginal Likelihood: -8.1420259475708
# Iter: 388, Log Marginal Likelihood: -8.130739212036133
# Iter: 389, Log Marginal Likelihood: -8.119558334350586
# Iter: 390, Log Marginal Likelihood: -8.10845947265625
# Iter: 391, Log Marginal Likelihood: -8.09748649597168
# Iter: 392, Log Marginal Likelihood: -8.086599349975586
# Iter: 393, Log Marginal Likelihood: -8.07580280303955
# Iter: 394, Log Marginal Likelihood: -8.065118789672852
# Iter: 395, Log Marginal Likelihood: -8.05451774597168
# Iter: 396, Log Marginal Likelihood: -8.044017791748047
# Iter: 397, Log Marginal Likelihood: -8.033613204956055
# Iter: 398, Log Marginal Likelihood: -8.023301124572754
# Iter: 399, Log Marginal Likelihood: -8.013083457946777
# Iter: 400, Log Marginal Likelihood: -8.00295352935791
# Iter: 401, Log Marginal Likelihood: -7.992918968200684
# Iter: 402, Log Marginal Likelihood: -7.982976913452148
# Iter: 403, Log Marginal Likelihood: -7.9731292724609375
# Iter: 404, Log Marginal Likelihood: -7.9633588790893555
# Iter: 405, Log Marginal Likelihood: -7.953678131103516
# Iter: 406, Log Marginal Likelihood: -7.944110870361328
# Iter: 407, Log Marginal Likelihood: -7.934598922729492
# Iter: 408, Log Marginal Likelihood: -7.925195693969727
# Iter: 409, Log Marginal Likelihood: -7.915868759155273
# Iter: 410, Log Marginal Likelihood: -7.906635284423828
# Iter: 411, Log Marginal Likelihood: -7.897459983825684
# Iter: 412, Log Marginal Likelihood: -7.888416290283203
# Iter: 413, Log Marginal Likelihood: -7.879426002502441
# Iter: 414, Log Marginal Likelihood: -7.870519638061523
# Iter: 415, Log Marginal Likelihood: -7.861698150634766
# Iter: 416, Log Marginal Likelihood: -7.852960586547852
# Iter: 417, Log Marginal Likelihood: -7.844305038452148
# Iter: 418, Log Marginal Likelihood: -7.835725784301758
# Iter: 419, Log Marginal Likelihood: -7.827239036560059
# Iter: 420, Log Marginal Likelihood: -7.818820953369141
# Iter: 421, Log Marginal Likelihood: -7.810482025146484
# Iter: 422, Log Marginal Likelihood: -7.802212715148926
# Iter: 423, Log Marginal Likelihood: -7.794031143188477
# Iter: 424, Log Marginal Likelihood: -7.785913467407227
# Iter: 425, Log Marginal Likelihood: -7.77789306640625
# Iter: 426, Log Marginal Likelihood: -7.769932746887207
# Iter: 427, Log Marginal Likelihood: -7.76204776763916
# Iter: 428, Log Marginal Likelihood: -7.754230499267578
# Iter: 429, Log Marginal Likelihood: -7.746498107910156
# Iter: 430, Log Marginal Likelihood: -7.738821983337402
# Iter: 431, Log Marginal Likelihood: -7.731245040893555
# Iter: 432, Log Marginal Likelihood: -7.723740577697754
# Iter: 433, Log Marginal Likelihood: -7.716278076171875
# Iter: 434, Log Marginal Likelihood: -7.7089033126831055
# Iter: 435, Log Marginal Likelihood: -7.701592445373535
# Iter: 436, Log Marginal Likelihood: -7.694355010986328
# Iter: 437, Log Marginal Likelihood: -7.687187194824219
# Iter: 438, Log Marginal Likelihood: -7.680079460144043
# Iter: 439, Log Marginal Likelihood: -7.673042297363281
# Iter: 440, Log Marginal Likelihood: -7.666065216064453
# Iter: 441, Log Marginal Likelihood: -7.659154891967773
# Iter: 442, Log Marginal Likelihood: -7.6523237228393555
# Iter: 443, Log Marginal Likelihood: -7.645543098449707
# Iter: 444, Log Marginal Likelihood: -7.638824462890625
# Iter: 445, Log Marginal Likelihood: -7.632177352905273
# Iter: 446, Log Marginal Likelihood: -7.625583648681641
# Iter: 447, Log Marginal Likelihood: -7.619081497192383
# Iter: 448, Log Marginal Likelihood: -7.612619400024414
# Iter: 449, Log Marginal Likelihood: -7.606224060058594
# Iter: 450, Log Marginal Likelihood: -7.59989070892334
# Iter: 451, Log Marginal Likelihood: -7.593601226806641
# Iter: 452, Log Marginal Likelihood: -7.5873823165893555
# Iter: 453, Log Marginal Likelihood: -7.581223487854004
# Iter: 454, Log Marginal Likelihood: -7.575117111206055
# Iter: 455, Log Marginal Likelihood: -7.569087028503418
# Iter: 456, Log Marginal Likelihood: -7.563092231750488
# Iter: 457, Log Marginal Likelihood: -7.557160377502441
# Iter: 458, Log Marginal Likelihood: -7.551279067993164
# Iter: 459, Log Marginal Likelihood: -7.545454025268555
# Iter: 460, Log Marginal Likelihood: -7.539709091186523
# Iter: 461, Log Marginal Likelihood: -7.533993721008301
# Iter: 462, Log Marginal Likelihood: -7.528341293334961
# Iter: 463, Log Marginal Likelihood: -7.522744178771973
# Iter: 464, Log Marginal Likelihood: -7.517192840576172
# Iter: 465, Log Marginal Likelihood: -7.511700630187988
# Iter: 466, Log Marginal Likelihood: -7.506248474121094
# Iter: 467, Log Marginal Likelihood: -7.500865936279297
# Iter: 468, Log Marginal Likelihood: -7.495525360107422
# Iter: 469, Log Marginal Likelihood: -7.490232467651367
# Iter: 470, Log Marginal Likelihood: -7.484992027282715
# Iter: 471, Log Marginal Likelihood: -7.479815483093262
# Iter: 472, Log Marginal Likelihood: -7.474664688110352
# Iter: 473, Log Marginal Likelihood: -7.469585418701172
# Iter: 474, Log Marginal Likelihood: -7.464535713195801
# Iter: 475, Log Marginal Likelihood: -7.459541320800781
# Iter: 476, Log Marginal Likelihood: -7.454591751098633
# Iter: 477, Log Marginal Likelihood: -7.449697494506836
# Iter: 478, Log Marginal Likelihood: -7.444840431213379
# Iter: 479, Log Marginal Likelihood: -7.440023422241211
# Iter: 480, Log Marginal Likelihood: -7.435258865356445
# Iter: 481, Log Marginal Likelihood: -7.430529594421387
# Iter: 482, Log Marginal Likelihood: -7.425875663757324
# Iter: 483, Log Marginal Likelihood: -7.421233177185059
# Iter: 484, Log Marginal Likelihood: -7.416650772094727
# Iter: 485, Log Marginal Likelihood: -7.412108421325684
# Iter: 486, Log Marginal Likelihood: -7.40760612487793
# Iter: 487, Log Marginal Likelihood: -7.403143882751465
# Iter: 488, Log Marginal Likelihood: -7.3987321853637695
# Iter: 489, Log Marginal Likelihood: -7.394339561462402
# Iter: 490, Log Marginal Likelihood: -7.390024185180664
# Iter: 491, Log Marginal Likelihood: -7.385736465454102
# Iter: 492, Log Marginal Likelihood: -7.381475448608398
# Iter: 493, Log Marginal Likelihood: -7.377249717712402
# Iter: 494, Log Marginal Likelihood: -7.373080253601074
# Iter: 495, Log Marginal Likelihood: -7.368947982788086
# Iter: 496, Log Marginal Likelihood: -7.364850044250488
# Iter: 497, Log Marginal Likelihood: -7.360801696777344
# Iter: 498, Log Marginal Likelihood: -7.356778144836426
# Iter: 499, Log Marginal Likelihood: -7.352786064147949
# Iter: 500, Log Marginal Likelihood: -7.348842620849609
# Iter: 501, Log Marginal Likelihood: -7.344945907592773
# Iter: 502, Log Marginal Likelihood: -7.341087341308594
# Iter: 503, Log Marginal Likelihood: -7.337226867675781
# Iter: 504, Log Marginal Likelihood: -7.3334197998046875
# Iter: 505, Log Marginal Likelihood: -7.329652786254883
# Iter: 506, Log Marginal Likelihood: -7.325937271118164
# Iter: 507, Log Marginal Likelihood: -7.322226524353027
# Iter: 508, Log Marginal Likelihood: -7.318572998046875
# Iter: 509, Log Marginal Likelihood: -7.314948081970215
# Iter: 510, Log Marginal Likelihood: -7.311361312866211
# Iter: 511, Log Marginal Likelihood: -7.307790756225586
# Iter: 512, Log Marginal Likelihood: -7.304264068603516
# Iter: 513, Log Marginal Likelihood: -7.30076789855957
# Iter: 514, Log Marginal Likelihood: -7.297309875488281
# Iter: 515, Log Marginal Likelihood: -7.293876647949219
# Iter: 516, Log Marginal Likelihood: -7.290467262268066
# Iter: 517, Log Marginal Likelihood: -7.287101745605469
# Iter: 518, Log Marginal Likelihood: -7.28375244140625
# Iter: 519, Log Marginal Likelihood: -7.280462265014648
# Iter: 520, Log Marginal Likelihood: -7.277209281921387
# Iter: 521, Log Marginal Likelihood: -7.27392578125
# Iter: 522, Log Marginal Likelihood: -7.2707014083862305
# Iter: 523, Log Marginal Likelihood: -7.26751708984375
# Iter: 524, Log Marginal Likelihood: -7.264351844787598
# Iter: 525, Log Marginal Likelihood: -7.261220932006836
# Iter: 526, Log Marginal Likelihood: -7.258119583129883
# Iter: 527, Log Marginal Likelihood: -7.255046844482422
# Iter: 528, Log Marginal Likelihood: -7.252010345458984
# Iter: 529, Log Marginal Likelihood: -7.248968124389648
# Iter: 530, Log Marginal Likelihood: -7.245997428894043
# Iter: 531, Log Marginal Likelihood: -7.243012428283691
# Iter: 532, Log Marginal Likelihood: -7.240090370178223
# Iter: 533, Log Marginal Likelihood: -7.237186431884766
# Iter: 534, Log Marginal Likelihood: -7.234277725219727
# Iter: 535, Log Marginal Likelihood: -7.231412887573242
# Iter: 536, Log Marginal Likelihood: -7.228588104248047
# Iter: 537, Log Marginal Likelihood: -7.225787162780762
# Iter: 538, Log Marginal Likelihood: -7.222990036010742
# Iter: 539, Log Marginal Likelihood: -7.220229148864746
# Iter: 540, Log Marginal Likelihood: -7.217491149902344
# Iter: 541, Log Marginal Likelihood: -7.214800834655762
# Iter: 542, Log Marginal Likelihood: -7.212100028991699
# Iter: 543, Log Marginal Likelihood: -7.209439277648926
# Iter: 544, Log Marginal Likelihood: -7.206798553466797
# Iter: 545, Log Marginal Likelihood: -7.204179763793945
# Iter: 546, Log Marginal Likelihood: -7.20158576965332
# Iter: 547, Log Marginal Likelihood: -7.19902229309082
# Iter: 548, Log Marginal Likelihood: -7.196481704711914
# Iter: 549, Log Marginal Likelihood: -7.193947792053223
# Iter: 550, Log Marginal Likelihood: -7.191439628601074
# Iter: 551, Log Marginal Likelihood: -7.188974380493164
# Iter: 552, Log Marginal Likelihood: -7.186491966247559
# Iter: 553, Log Marginal Likelihood: -7.184059143066406
# Iter: 554, Log Marginal Likelihood: -7.181645393371582
# Iter: 555, Log Marginal Likelihood: -7.17924690246582
# Iter: 556, Log Marginal Likelihood: -7.176889419555664
# Iter: 557, Log Marginal Likelihood: -7.174503326416016
# Iter: 558, Log Marginal Likelihood: -7.172184944152832
# Iter: 559, Log Marginal Likelihood: -7.169869422912598
# Iter: 560, Log Marginal Likelihood: -7.1675567626953125
# Iter: 561, Log Marginal Likelihood: -7.165287971496582
# Iter: 562, Log Marginal Likelihood: -7.163020133972168
# Iter: 563, Log Marginal Likelihood: -7.160808563232422
# Iter: 564, Log Marginal Likelihood: -7.158583641052246
# Iter: 565, Log Marginal Likelihood: -7.156375885009766
# Iter: 566, Log Marginal Likelihood: -7.154205322265625
# Iter: 567, Log Marginal Likelihood: -7.152036666870117
# Iter: 568, Log Marginal Likelihood: -7.14990234375
# Iter: 569, Log Marginal Likelihood: -7.147774696350098
# Iter: 570, Log Marginal Likelihood: -7.145679473876953
# Iter: 571, Log Marginal Likelihood: -7.143590927124023
# Iter: 572, Log Marginal Likelihood: -7.141513824462891
# Iter: 573, Log Marginal Likelihood: -7.139447212219238
# Iter: 574, Log Marginal Likelihood: -7.137413024902344
# Iter: 575, Log Marginal Likelihood: -7.135385513305664
# Iter: 576, Log Marginal Likelihood: -7.133390426635742
# Iter: 577, Log Marginal Likelihood: -7.131402969360352
# Iter: 578, Log Marginal Likelihood: -7.129441261291504
# Iter: 579, Log Marginal Likelihood: -7.127476692199707
# Iter: 580, Log Marginal Likelihood: -7.125544548034668
# Iter: 581, Log Marginal Likelihood: -7.123623847961426
# Iter: 582, Log Marginal Likelihood: -7.121709823608398
# Iter: 583, Log Marginal Likelihood: -7.119838714599609
# Iter: 584, Log Marginal Likelihood: -7.117972373962402
# Iter: 585, Log Marginal Likelihood: -7.116106033325195
# Iter: 586, Log Marginal Likelihood: -7.114261627197266
# Iter: 587, Log Marginal Likelihood: -7.112422943115234
# Iter: 588, Log Marginal Likelihood: -7.110616683959961
# Iter: 589, Log Marginal Likelihood: -7.108816146850586
# Iter: 590, Log Marginal Likelihood: -7.107036590576172
# Iter: 591, Log Marginal Likelihood: -7.10526180267334
# Iter: 592, Log Marginal Likelihood: -7.103507995605469
# Iter: 593, Log Marginal Likelihood: -7.10176944732666
# Iter: 594, Log Marginal Likelihood: -7.100044250488281
# Iter: 595, Log Marginal Likelihood: -7.098323822021484
# Iter: 596, Log Marginal Likelihood: -7.096635818481445
# Iter: 597, Log Marginal Likelihood: -7.094938278198242
# Iter: 598, Log Marginal Likelihood: -7.093267440795898
# Iter: 599, Log Marginal Likelihood: -7.091616630554199
# Iter: 600, Log Marginal Likelihood: -7.089971542358398
# Iter: 601, Log Marginal Likelihood: -7.088329315185547
# Iter: 602, Log Marginal Likelihood: -7.086740493774414
# Iter: 603, Log Marginal Likelihood: -7.085109710693359
# Iter: 604, Log Marginal Likelihood: -7.083515167236328
# Iter: 605, Log Marginal Likelihood: -7.081936836242676
# Iter: 606, Log Marginal Likelihood: -7.080375671386719
# Iter: 607, Log Marginal Likelihood: -7.078784942626953
# Iter: 608, Log Marginal Likelihood: -7.0772552490234375
# Iter: 609, Log Marginal Likelihood: -7.075714111328125
# Iter: 610, Log Marginal Likelihood: -7.074222564697266
# Iter: 611, Log Marginal Likelihood: -7.072699546813965
# Iter: 612, Log Marginal Likelihood: -7.071219444274902
# Iter: 613, Log Marginal Likelihood: -7.069708824157715
# Iter: 614, Log Marginal Likelihood: -7.06825065612793
# Iter: 615, Log Marginal Likelihood: -7.066784858703613
# Iter: 616, Log Marginal Likelihood: -7.065326690673828
# Iter: 617, Log Marginal Likelihood: -7.063905715942383
# Iter: 618, Log Marginal Likelihood: -7.062475204467773
# Iter: 619, Log Marginal Likelihood: -7.061061859130859
# Iter: 620, Log Marginal Likelihood: -7.059636116027832
# Iter: 621, Log Marginal Likelihood: -7.058243751525879
# Iter: 622, Log Marginal Likelihood: -7.056853294372559
# Iter: 623, Log Marginal Likelihood: -7.055480003356934
# Iter: 624, Log Marginal Likelihood: -7.054134368896484
# Iter: 625, Log Marginal Likelihood: -7.052768707275391
# Iter: 626, Log Marginal Likelihood: -7.051408767700195
# Iter: 627, Log Marginal Likelihood: -7.0500946044921875
# Iter: 628, Log Marginal Likelihood: -7.048759460449219
# Iter: 629, Log Marginal Likelihood: -7.047446250915527
# Iter: 630, Log Marginal Likelihood: -7.046164512634277
# Iter: 631, Log Marginal Likelihood: -7.04486083984375
# Iter: 632, Log Marginal Likelihood: -7.043577194213867
# Iter: 633, Log Marginal Likelihood: -7.04231071472168
# Iter: 634, Log Marginal Likelihood: -7.04102897644043
# Iter: 635, Log Marginal Likelihood: -7.039767265319824
# Iter: 636, Log Marginal Likelihood: -7.0385284423828125
# Iter: 637, Log Marginal Likelihood: -7.037284851074219
# Iter: 638, Log Marginal Likelihood: -7.03605842590332
# Iter: 639, Log Marginal Likelihood: -7.0348405838012695
# Iter: 640, Log Marginal Likelihood: -7.033624649047852
# Iter: 641, Log Marginal Likelihood: -7.032434463500977
# Iter: 642, Log Marginal Likelihood: -7.031230926513672
# Iter: 643, Log Marginal Likelihood: -7.030060768127441
# Iter: 644, Log Marginal Likelihood: -7.028883934020996
# Iter: 645, Log Marginal Likelihood: -7.027704238891602
# Iter: 646, Log Marginal Likelihood: -7.0265350341796875
# Iter: 647, Log Marginal Likelihood: -7.025371551513672
# Iter: 648, Log Marginal Likelihood: -7.024253845214844
# Iter: 649, Log Marginal Likelihood: -7.023134231567383
# Iter: 650, Log Marginal Likelihood: -7.021997451782227
# Iter: 651, Log Marginal Likelihood: -7.020869255065918
# Iter: 652, Log Marginal Likelihood: -7.019767761230469
# Iter: 653, Log Marginal Likelihood: -7.018659591674805
# Iter: 654, Log Marginal Likelihood: -7.017575263977051
# Iter: 655, Log Marginal Likelihood: -7.016497611999512
# Iter: 656, Log Marginal Likelihood: -7.015440940856934
# Iter: 657, Log Marginal Likelihood: -7.0143327713012695
# Iter: 658, Log Marginal Likelihood: -7.013286590576172
# Iter: 659, Log Marginal Likelihood: -7.012218475341797
# Iter: 660, Log Marginal Likelihood: -7.011178016662598
# Iter: 661, Log Marginal Likelihood: -7.010149002075195
# Iter: 662, Log Marginal Likelihood: -7.0091047286987305
# Iter: 663, Log Marginal Likelihood: -7.008066177368164
# Iter: 664, Log Marginal Likelihood: -7.007055282592773
# Iter: 665, Log Marginal Likelihood: -7.006053924560547
# Iter: 666, Log Marginal Likelihood: -7.005029678344727
# Iter: 667, Log Marginal Likelihood: -7.004011154174805
# Iter: 668, Log Marginal Likelihood: -7.003045082092285
# Iter: 669, Log Marginal Likelihood: -7.002072334289551
# Iter: 670, Log Marginal Likelihood: -7.001067161560059
# Iter: 671, Log Marginal Likelihood: -7.000103950500488
# Iter: 672, Log Marginal Likelihood: -6.999155044555664
# Iter: 673, Log Marginal Likelihood: -6.998195648193359
# Iter: 674, Log Marginal Likelihood: -6.997245788574219
# Iter: 675, Log Marginal Likelihood: -6.996305465698242
# Iter: 676, Log Marginal Likelihood: -6.995349884033203
# Iter: 677, Log Marginal Likelihood: -6.994405746459961
# Iter: 678, Log Marginal Likelihood: -6.993492126464844
# Iter: 679, Log Marginal Likelihood: -6.992565155029297
# Iter: 680, Log Marginal Likelihood: -6.991650581359863
# Iter: 681, Log Marginal Likelihood: -6.9907426834106445
# Iter: 682, Log Marginal Likelihood: -6.98985481262207
# Iter: 683, Log Marginal Likelihood: -6.988964080810547
# Iter: 684, Log Marginal Likelihood: -6.988061904907227
# Iter: 685, Log Marginal Likelihood: -6.9871931076049805
# Iter: 686, Log Marginal Likelihood: -6.986311912536621
# Iter: 687, Log Marginal Likelihood: -6.985431671142578
# Iter: 688, Log Marginal Likelihood: -6.984577178955078
# Iter: 689, Log Marginal Likelihood: -6.983699798583984
# Iter: 690, Log Marginal Likelihood: -6.9828691482543945
# Iter: 691, Log Marginal Likelihood: -6.982030868530273
# Iter: 692, Log Marginal Likelihood: -6.9811553955078125
# Iter: 693, Log Marginal Likelihood: -6.980329513549805
# Iter: 694, Log Marginal Likelihood: -6.979496002197266
# Iter: 695, Log Marginal Likelihood: -6.978662490844727
# Iter: 696, Log Marginal Likelihood: -6.977840423583984
# Iter: 697, Log Marginal Likelihood: -6.977053642272949
# Iter: 698, Log Marginal Likelihood: -6.976215362548828
# Iter: 699, Log Marginal Likelihood: -6.975405693054199
# Iter: 700, Log Marginal Likelihood: -6.974611282348633
# Iter: 701, Log Marginal Likelihood: -6.973827362060547
# Iter: 702, Log Marginal Likelihood: -6.973028182983398
# Iter: 703, Log Marginal Likelihood: -6.9722394943237305
# Iter: 704, Log Marginal Likelihood: -6.971453666687012
# Iter: 705, Log Marginal Likelihood: -6.970682144165039
# Iter: 706, Log Marginal Likelihood: -6.969913482666016
# Iter: 707, Log Marginal Likelihood: -6.969158172607422
# Iter: 708, Log Marginal Likelihood: -6.968389511108398
# Iter: 709, Log Marginal Likelihood: -6.967619895935059
# Iter: 710, Log Marginal Likelihood: -6.96689510345459
# Iter: 711, Log Marginal Likelihood: -6.966136932373047
# Iter: 712, Log Marginal Likelihood: -6.965383529663086
# Iter: 713, Log Marginal Likelihood: -6.964646339416504
# Iter: 714, Log Marginal Likelihood: -6.963922500610352
# Iter: 715, Log Marginal Likelihood: -6.963172912597656
# Iter: 716, Log Marginal Likelihood: -6.962454795837402
# Iter: 717, Log Marginal Likelihood: -6.96174430847168
# Iter: 718, Log Marginal Likelihood: -6.961051940917969
# Iter: 719, Log Marginal Likelihood: -6.960332870483398
# Iter: 720, Log Marginal Likelihood: -6.959634780883789
# Iter: 721, Log Marginal Likelihood: -6.958932876586914
# Iter: 722, Log Marginal Likelihood: -6.958221435546875
# Iter: 723, Log Marginal Likelihood: -6.957544326782227
# Iter: 724, Log Marginal Likelihood: -6.956849098205566
# Iter: 725, Log Marginal Likelihood: -6.956147193908691
# Iter: 726, Log Marginal Likelihood: -6.955474853515625
# Iter: 727, Log Marginal Likelihood: -6.954828262329102
# Iter: 728, Log Marginal Likelihood: -6.954137802124023
# Iter: 729, Log Marginal Likelihood: -6.9534759521484375
# Iter: 730, Log Marginal Likelihood: -6.952805519104004
# Iter: 731, Log Marginal Likelihood: -6.952144622802734
# Iter: 732, Log Marginal Likelihood: -6.951469421386719
# Iter: 733, Log Marginal Likelihood: -6.950852394104004
# Iter: 734, Log Marginal Likelihood: -6.950182914733887
# Iter: 735, Log Marginal Likelihood: -6.949552536010742
# Iter: 736, Log Marginal Likelihood: -6.948888778686523
# Iter: 737, Log Marginal Likelihood: -6.94828987121582
# Iter: 738, Log Marginal Likelihood: -6.947644233703613
# Iter: 739, Log Marginal Likelihood: -6.947020530700684
# Iter: 740, Log Marginal Likelihood: -6.946386337280273
# Iter: 741, Log Marginal Likelihood: -6.945765495300293
# Iter: 742, Log Marginal Likelihood: -6.945150375366211
# Iter: 743, Log Marginal Likelihood: -6.944546699523926
# Iter: 744, Log Marginal Likelihood: -6.943934440612793
# Iter: 745, Log Marginal Likelihood: -6.943317413330078
# Iter: 746, Log Marginal Likelihood: -6.942721366882324
# Iter: 747, Log Marginal Likelihood: -6.942113876342773
# Iter: 748, Log Marginal Likelihood: -6.941532135009766
# Iter: 749, Log Marginal Likelihood: -6.9409379959106445
# Iter: 750, Log Marginal Likelihood: -6.940332412719727
# Iter: 751, Log Marginal Likelihood: -6.939759254455566
# Iter: 752, Log Marginal Likelihood: -6.939166069030762
# Iter: 753, Log Marginal Likelihood: -6.938589096069336
# Iter: 754, Log Marginal Likelihood: -6.93802547454834
# Iter: 755, Log Marginal Likelihood: -6.937448501586914
# Iter: 756, Log Marginal Likelihood: -6.936857223510742
# Iter: 757, Log Marginal Likelihood: -6.936311721801758
# Iter: 758, Log Marginal Likelihood: -6.935763359069824
# Iter: 759, Log Marginal Likelihood: -6.935179710388184
# Iter: 760, Log Marginal Likelihood: -6.934634208679199
# Iter: 761, Log Marginal Likelihood: -6.934085845947266
# Iter: 762, Log Marginal Likelihood: -6.9335479736328125
# Iter: 763, Log Marginal Likelihood: -6.932997703552246
# Iter: 764, Log Marginal Likelihood: -6.932460784912109
# Iter: 765, Log Marginal Likelihood: -6.931915283203125
# Iter: 766, Log Marginal Likelihood: -6.931392669677734
# Iter: 767, Log Marginal Likelihood: -6.9308624267578125
# Iter: 768, Log Marginal Likelihood: -6.930315017700195
# Iter: 769, Log Marginal Likelihood: -6.929784774780273
# Iter: 770, Log Marginal Likelihood: -6.929266929626465
# Iter: 771, Log Marginal Likelihood: -6.928750038146973
# Iter: 772, Log Marginal Likelihood: -6.928210258483887
# Iter: 773, Log Marginal Likelihood: -6.927704811096191
# Iter: 774, Log Marginal Likelihood: -6.927170753479004
# Iter: 775, Log Marginal Likelihood: -6.926662445068359
# Iter: 776, Log Marginal Likelihood: -6.926174163818359
# Iter: 777, Log Marginal Likelihood: -6.925661087036133
# Iter: 778, Log Marginal Likelihood: -6.925163269042969
# Iter: 779, Log Marginal Likelihood: -6.924666404724121
# Iter: 780, Log Marginal Likelihood: -6.9241790771484375
# Iter: 781, Log Marginal Likelihood: -6.923662185668945
# Iter: 782, Log Marginal Likelihood: -6.92315673828125
# Iter: 783, Log Marginal Likelihood: -6.9227142333984375
# Iter: 784, Log Marginal Likelihood: -6.922208786010742
# Iter: 785, Log Marginal Likelihood: -6.921716690063477
# Iter: 786, Log Marginal Likelihood: -6.921229362487793
# Iter: 787, Log Marginal Likelihood: -6.920758247375488
# Iter: 788, Log Marginal Likelihood: -6.920295715332031
# Iter: 789, Log Marginal Likelihood: -6.919826507568359
# Iter: 790, Log Marginal Likelihood: -6.919333457946777
# Iter: 791, Log Marginal Likelihood: -6.918889999389648
# Iter: 792, Log Marginal Likelihood: -6.918416976928711
# Iter: 793, Log Marginal Likelihood: -6.917956352233887
# Iter: 794, Log Marginal Likelihood: -6.917485237121582
# Iter: 795, Log Marginal Likelihood: -6.917023658752441
# Iter: 796, Log Marginal Likelihood: -6.9165802001953125
# Iter: 797, Log Marginal Likelihood: -6.916131019592285
# Iter: 798, Log Marginal Likelihood: -6.915643692016602
# Iter: 799, Log Marginal Likelihood: -6.915238380432129
# Iter: 800, Log Marginal Likelihood: -6.914775848388672
# Iter: 801, Log Marginal Likelihood: -6.914327621459961
# Iter: 802, Log Marginal Likelihood: -6.913906097412109
# Iter: 803, Log Marginal Likelihood: -6.913455009460449
# Iter: 804, Log Marginal Likelihood: -6.913018226623535
# Iter: 805, Log Marginal Likelihood: -6.912599563598633
# Iter: 806, Log Marginal Likelihood: -6.912168502807617
# Iter: 807, Log Marginal Likelihood: -6.911717414855957
# Iter: 808, Log Marginal Likelihood: -6.911291122436523
# Iter: 809, Log Marginal Likelihood: -6.910872459411621
# Iter: 810, Log Marginal Likelihood: -6.910442352294922
# Iter: 811, Log Marginal Likelihood: -6.910043716430664
# Iter: 812, Log Marginal Likelihood: -6.909618377685547
# Iter: 813, Log Marginal Likelihood: -6.909191131591797
# Iter: 814, Log Marginal Likelihood: -6.9087629318237305
# Iter: 815, Log Marginal Likelihood: -6.908354759216309
# Iter: 816, Log Marginal Likelihood: -6.907939910888672
# Iter: 817, Log Marginal Likelihood: -6.9075469970703125
# Iter: 818, Log Marginal Likelihood: -6.907135963439941
# Iter: 819, Log Marginal Likelihood: -6.906745910644531
# Iter: 820, Log Marginal Likelihood: -6.906335830688477
# Iter: 821, Log Marginal Likelihood: -6.905953407287598
# Iter: 822, Log Marginal Likelihood: -6.905555725097656
# Iter: 823, Log Marginal Likelihood: -6.905145645141602
# Iter: 824, Log Marginal Likelihood: -6.904742240905762
# Iter: 825, Log Marginal Likelihood: -6.904358863830566
# Iter: 826, Log Marginal Likelihood: -6.903980255126953
# Iter: 827, Log Marginal Likelihood: -6.9035797119140625
# Iter: 828, Log Marginal Likelihood: -6.9031982421875
# Iter: 829, Log Marginal Likelihood: -6.902805328369141
# Iter: 830, Log Marginal Likelihood: -6.902431488037109
# Iter: 831, Log Marginal Likelihood: -6.902050018310547
# Iter: 832, Log Marginal Likelihood: -6.901673316955566
# Iter: 833, Log Marginal Likelihood: -6.901304244995117
# Iter: 834, Log Marginal Likelihood: -6.900947570800781
# Iter: 835, Log Marginal Likelihood: -6.900576591491699
# Iter: 836, Log Marginal Likelihood: -6.900198936462402
# Iter: 837, Log Marginal Likelihood: -6.899816513061523
# Iter: 838, Log Marginal Likelihood: -6.899450302124023
# Iter: 839, Log Marginal Likelihood: -6.899069786071777
# Iter: 840, Log Marginal Likelihood: -6.898710250854492
# Iter: 841, Log Marginal Likelihood: -6.898368835449219
# Iter: 842, Log Marginal Likelihood: -6.898027420043945
# Iter: 843, Log Marginal Likelihood: -6.89763069152832
# Iter: 844, Log Marginal Likelihood: -6.897311210632324
# Iter: 845, Log Marginal Likelihood: -6.896943092346191
# Iter: 846, Log Marginal Likelihood: -6.896576881408691
# Iter: 847, Log Marginal Likelihood: -6.896235466003418
# Iter: 848, Log Marginal Likelihood: -6.895895957946777
# Iter: 849, Log Marginal Likelihood: -6.895549774169922
# Iter: 850, Log Marginal Likelihood: -6.895205497741699
# Iter: 851, Log Marginal Likelihood: -6.89483642578125
# Iter: 852, Log Marginal Likelihood: -6.894486427307129
# Iter: 853, Log Marginal Likelihood: -6.894145965576172
# Iter: 854, Log Marginal Likelihood: -6.893838882446289
# Iter: 855, Log Marginal Likelihood: -6.893474578857422
# Iter: 856, Log Marginal Likelihood: -6.893145561218262
# Iter: 857, Log Marginal Likelihood: -6.892826080322266
# Iter: 858, Log Marginal Likelihood: -6.89249324798584
# Iter: 859, Log Marginal Likelihood: -6.892138481140137
# Iter: 860, Log Marginal Likelihood: -6.891834259033203
# Iter: 861, Log Marginal Likelihood: -6.89149284362793
# Iter: 862, Log Marginal Likelihood: -6.891172409057617
# Iter: 863, Log Marginal Likelihood: -6.890865325927734
# Iter: 864, Log Marginal Likelihood: -6.890521049499512
# Iter: 865, Log Marginal Likelihood: -6.890190124511719
# Iter: 866, Log Marginal Likelihood: -6.889888763427734
# Iter: 867, Log Marginal Likelihood: -6.889554977416992
# Iter: 868, Log Marginal Likelihood: -6.889245986938477
# Iter: 869, Log Marginal Likelihood: -6.888940811157227
# Iter: 870, Log Marginal Likelihood: -6.888643264770508
# Iter: 871, Log Marginal Likelihood: -6.888311386108398
# Iter: 872, Log Marginal Likelihood: -6.888016700744629
# Iter: 873, Log Marginal Likelihood: -6.88767147064209
# Iter: 874, Log Marginal Likelihood: -6.887372016906738
# Iter: 875, Log Marginal Likelihood: -6.887090682983398
# Iter: 876, Log Marginal Likelihood: -6.88675594329834
# Iter: 877, Log Marginal Likelihood: -6.886465072631836
# Iter: 878, Log Marginal Likelihood: -6.886171340942383
# Iter: 879, Log Marginal Likelihood: -6.885858535766602
# Iter: 880, Log Marginal Likelihood: -6.885591506958008
# Iter: 881, Log Marginal Likelihood: -6.885259628295898
# Iter: 882, Log Marginal Likelihood: -6.884975433349609
# Iter: 883, Log Marginal Likelihood: -6.8846588134765625
# Iter: 884, Log Marginal Likelihood: -6.8843841552734375
# Iter: 885, Log Marginal Likelihood: -6.884078025817871
# Iter: 886, Log Marginal Likelihood: -6.8837890625
# Iter: 887, Log Marginal Likelihood: -6.883512496948242
# Iter: 888, Log Marginal Likelihood: -6.883177757263184
# Iter: 889, Log Marginal Likelihood: -6.882902145385742
# Iter: 890, Log Marginal Likelihood: -6.882626533508301
# Iter: 891, Log Marginal Likelihood: -6.882358551025391
# Iter: 892, Log Marginal Likelihood: -6.882065773010254
# Iter: 893, Log Marginal Likelihood: -6.881805419921875
# Iter: 894, Log Marginal Likelihood: -6.881495475769043
# Iter: 895, Log Marginal Likelihood: -6.881242752075195
# Iter: 896, Log Marginal Likelihood: -6.880939483642578
# Iter: 897, Log Marginal Likelihood: -6.88066291809082
# Iter: 898, Log Marginal Likelihood: -6.880400657653809
# Iter: 899, Log Marginal Likelihood: -6.880110740661621
# Iter: 900, Log Marginal Likelihood: -6.87985897064209
# Iter: 901, Log Marginal Likelihood: -6.879565238952637
# Iter: 902, Log Marginal Likelihood: -6.879310607910156
# Iter: 903, Log Marginal Likelihood: -6.879037857055664
# Iter: 904, Log Marginal Likelihood: -6.878737449645996
# Iter: 905, Log Marginal Likelihood: -6.8784942626953125
# Iter: 906, Log Marginal Likelihood: -6.878242492675781
# Iter: 907, Log Marginal Likelihood: -6.877963066101074
# Iter: 908, Log Marginal Likelihood: -6.87769889831543
# Iter: 909, Log Marginal Likelihood: -6.877449035644531
# Iter: 910, Log Marginal Likelihood: -6.877166748046875
# Iter: 911, Log Marginal Likelihood: -6.876900672912598
# Iter: 912, Log Marginal Likelihood: -6.87666130065918
# Iter: 913, Log Marginal Likelihood: -6.87640380859375
# Iter: 914, Log Marginal Likelihood: -6.87614631652832
# Iter: 915, Log Marginal Likelihood: -6.875879287719727
# Iter: 916, Log Marginal Likelihood: -6.875637054443359
# Iter: 917, Log Marginal Likelihood: -6.875389099121094
# Iter: 918, Log Marginal Likelihood: -6.8751220703125
# Iter: 919, Log Marginal Likelihood: -6.874869346618652
# Iter: 920, Log Marginal Likelihood: -6.874639511108398
# Iter: 921, Log Marginal Likelihood: -6.8743743896484375
# Iter: 922, Log Marginal Likelihood: -6.874133110046387
# Iter: 923, Log Marginal Likelihood: -6.873868942260742
# Iter: 924, Log Marginal Likelihood: -6.873631477355957
# Iter: 925, Log Marginal Likelihood: -6.873377799987793
# Iter: 926, Log Marginal Likelihood: -6.873163223266602
# Iter: 927, Log Marginal Likelihood: -6.872913360595703
# Iter: 928, Log Marginal Likelihood: -6.8726701736450195
# Iter: 929, Log Marginal Likelihood: -6.872429847717285
# Iter: 930, Log Marginal Likelihood: -6.872167587280273
# Iter: 931, Log Marginal Likelihood: -6.871970176696777
# Iter: 932, Log Marginal Likelihood: -6.871709823608398
# Iter: 933, Log Marginal Likelihood: -6.871442794799805
# Iter: 934, Log Marginal Likelihood: -6.871233940124512
# Iter: 935, Log Marginal Likelihood: -6.871015548706055
# Iter: 936, Log Marginal Likelihood: -6.870752334594727
# Iter: 937, Log Marginal Likelihood: -6.870527267456055
# Iter: 938, Log Marginal Likelihood: -6.870272636413574
# Iter: 939, Log Marginal Likelihood: -6.870075225830078
# Iter: 940, Log Marginal Likelihood: -6.869821548461914
# Iter: 941, Log Marginal Likelihood: -6.869612693786621
# Iter: 942, Log Marginal Likelihood: -6.869379043579102
# Iter: 943, Log Marginal Likelihood: -6.869140625
# Iter: 944, Log Marginal Likelihood: -6.868941307067871
# Iter: 945, Log Marginal Likelihood: -6.868712425231934
# Iter: 946, Log Marginal Likelihood: -6.868472099304199
# Iter: 947, Log Marginal Likelihood: -6.868278503417969
# Iter: 948, Log Marginal Likelihood: -6.868015289306641
# Iter: 949, Log Marginal Likelihood: -6.867823600769043
# Iter: 950, Log Marginal Likelihood: -6.867616653442383
# Iter: 951, Log Marginal Likelihood: -6.867393493652344
# Iter: 952, Log Marginal Likelihood: -6.867162704467773
# Iter: 953, Log Marginal Likelihood: -6.866955757141113
# Iter: 954, Log Marginal Likelihood: -6.866713523864746
# Iter: 955, Log Marginal Likelihood: -6.866518020629883
# Iter: 956, Log Marginal Likelihood: -6.86627197265625
# Iter: 957, Log Marginal Likelihood: -6.866085052490234
# Iter: 958, Log Marginal Likelihood: -6.865876197814941
# Iter: 959, Log Marginal Likelihood: -6.865667343139648
# Iter: 960, Log Marginal Likelihood: -6.865451812744141
# Iter: 961, Log Marginal Likelihood: -6.865227699279785
# Iter: 962, Log Marginal Likelihood: -6.865001678466797
# Iter: 963, Log Marginal Likelihood: -6.864797592163086
# Iter: 964, Log Marginal Likelihood: -6.8646135330200195
# Iter: 965, Log Marginal Likelihood: -6.864410400390625
# Iter: 966, Log Marginal Likelihood: -6.864174842834473
# Iter: 967, Log Marginal Likelihood: -6.863992691040039
# Iter: 968, Log Marginal Likelihood: -6.863779067993164
# Iter: 969, Log Marginal Likelihood: -6.86357307434082
# Iter: 970, Log Marginal Likelihood: -6.863368034362793
# Iter: 971, Log Marginal Likelihood: -6.863168716430664
# Iter: 972, Log Marginal Likelihood: -6.862980842590332
# Iter: 973, Log Marginal Likelihood: -6.862790107727051
# Iter: 974, Log Marginal Likelihood: -6.862532615661621
# Iter: 975, Log Marginal Likelihood: -6.862383842468262
# Iter: 976, Log Marginal Likelihood: -6.8621826171875
# Iter: 977, Log Marginal Likelihood: -6.86198616027832
# Iter: 978, Log Marginal Likelihood: -6.861777305603027
# Iter: 979, Log Marginal Likelihood: -6.861580848693848
# Iter: 980, Log Marginal Likelihood: -6.861376762390137
# Iter: 981, Log Marginal Likelihood: -6.861194610595703
# Iter: 982, Log Marginal Likelihood: -6.860992431640625
# Iter: 983, Log Marginal Likelihood: -6.8607940673828125
# Iter: 984, Log Marginal Likelihood: -6.860639572143555
# Iter: 985, Log Marginal Likelihood: -6.86043643951416
# Iter: 986, Log Marginal Likelihood: -6.860235214233398
# Iter: 987, Log Marginal Likelihood: -6.8600568771362305
# Iter: 988, Log Marginal Likelihood: -6.859834671020508
# Iter: 989, Log Marginal Likelihood: -6.859689712524414
# Iter: 990, Log Marginal Likelihood: -6.859463691711426
# Iter: 991, Log Marginal Likelihood: -6.859312057495117
# Iter: 992, Log Marginal Likelihood: -6.859109878540039
# Iter: 993, Log Marginal Likelihood: -6.858922004699707
# Iter: 994, Log Marginal Likelihood: -6.85874080657959
# Iter: 995, Log Marginal Likelihood: -6.858552932739258
# Iter: 996, Log Marginal Likelihood: -6.858376502990723
# Iter: 997, Log Marginal Likelihood: -6.858177185058594
# Iter: 998, Log Marginal Likelihood: -6.858003616333008
# Iter: 999, Log Marginal Likelihood: -6.857814788818359
# Optimized lengthscale: 1.8035181760787964
# Optimized outputscale: 0.642390251159668
# Optimized noise: 0.00889786146581173
